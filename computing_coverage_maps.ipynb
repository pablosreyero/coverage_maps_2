# %% [markdown]
# # Coverage map of a subset scene from a Madrid scenario

# %% [markdown]
# In this Notebook we are testing the feasibility of a custom made scene with Blender API being fed to Sionna

# %% [markdown]
# ### Imports and GPU configuration

# %%
import os
if os.getenv("CUDA_VISIBLE_DEVICES") is None:
    gpu_num = 0 # Use "" to use the CPU
    os.environ["CUDA_VISIBLE_DEVICES"] = f"{gpu_num}"
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

# Import Sionna
try:
    import sionna
except ImportError as e:
    # Install Sionna if package is not already installed
    import os
    os.system("pip install sionna")
    import sionna

# Configure the notebook to use only a single GPU and allocate only as much memory as needed
# For more details, see https://www.tensorflow.org/guide/gpu
import tensorflow as tf
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    try:
        tf.config.experimental.set_memory_growth(gpus[0], True)
    except RuntimeError as e:
        print(e)
tf.get_logger().setLevel('ERROR')

# Set random seed for reproducibility
sionna.config.seed = 42

# importing other libraries
# Sionna imports
from sionna.rt import load_scene, PlanarArray, Transmitter, Receiver, Camera, watt_to_dbm
from sionna.mimo.precoding import normalize_precoding_power, grid_of_beams_dft
from sionna.utils import log10

# Python importings
import gc 
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
try:
    import pandas as pd
except:
    os.system("pip install pandas")
    import pandas as pd

# file imports
#import custom_MSI

# %% [markdown]
# ## Useful functions

# %%
def extract_data(df, name):
    """
    This function retrieves coordinates, height, gains and tilt
    from the desired BS, given its ID
    """

    # print(df.head()) # Display the first few rows
    # print(df.dtypes)

    # preprocessing (preguntar a Rolando)        
    # filtered_df = df[(df['X(UTMHuso30)'] >= X_min) & (df['X(UTMHuso30)'] <= X_max) & (df['Y(UTMHuso30)'] >= Y_min) & (df['Y(UTMHuso30)'] <= Y_max)]
    # filtered_df.head()
    
    df_one_PROV_EMPLA = df[df["PROV_EMPLA"] == int(name)] # filter by PROV_EMPLA given by the name of the folder
    # print(f"Test whether the DF is empty or not: {df_one_PROV_EMPLA}")  # Display the filtered rows
    X_UTMHuso30 = df_one_PROV_EMPLA["X(UTMHuso30)"].tolist()
    Y_UTMHuso30 = df_one_PROV_EMPLA["Y(UTMHuso30)"].tolist()
    # print(f"Estas son las coordenadas: X_UTMHuso30: {X_UTMHuso30}")
    # print(f"Estas son las coordenadas: Y_UTMHuso30: {Y_UTMHuso30}")

    # let us convert the coordinates to an understandable format for Sionna --> relative location coordinates
    # x_location =  X_UTMHuso30 - X_min*np.ones_like(X_UTMHuso30) # ask Rolando
    # y_location =  Y_UTMHuso30 - Y_min*np.ones_like(Y_UTMHuso30)

    orientations = df_one_PROV_EMPLA["ORIENTACION"].tolist()
    gants = df_one_PROV_EMPLA["GANT"].tolist()
    alturas = df_one_PROV_EMPLA["altura"].tolist()
    tilts = df_one_PROV_EMPLA["tilt total"].tolist()

    return orientations, gants, alturas, tilts

def ensure_folder_exists(folder_path):
    """
    Checks if the folder exists, and if not, creates it.
    """
    if not os.path.exists(folder_path):
        os.makedirs(folder_path)
        print(f"Folder '{folder_path}' created.")
    else:
        print(f"Folder '{folder_path}' already exists.")

# def plotting_coverage_map(cm):
#     """
#     This function takes as argument the coverage map from Sionna
#     and plots it as Sionna does, but we implement a conversion to the axis. 
#     so that we can normalize the heat bar to better compare results
#     """

# %% [markdown]
# ### Now the main code

# %%
import datetime

cm_metric = "rss" # choose between: ["path_gain", "rss", "SINR"]
delete_previous_results = False
render_to_file = False

# First, let's start by retrieving the coords of the BS by getting the name of the folder and searching by its name on the dataset
directories = ["sionna_madrid" ,"sionna_madrid_concrete_ground"]
for directory in directories:
    error_file_path = os.path.join(directory, "error_logs.txt")
    for name in os.listdir(directory):
        # if os.path.isdir(os.path.join(directory, name)) and name != ".ipynb_checkpoints" and name not in ["2800930", "2800754"]:
        if os.path.isdir(os.path.join(directory, name)) and name != ".ipynb_checkpoints":
            print(f"Element: {name}")
            # cwd = os.getcwd()
            scene_dir = os.path.join(directory, name)
            # print(scene_dir)

            # if desired, delete previous results to purge directories
            if delete_previous_results:
                if os.path.isdir(os.path.join(directory, name)) and name != ".ipynb_checkpoints":
                    scene_dir = os.path.join(directory, name)
        
                    # let us delete the ancient PDFs
                    pdf_files = [file for file in os.listdir(scene_dir) if file.endswith(".pdf")]
                    for pdf in pdf_files:
                        path_pdf_i = os.path.join(scene_dir, str(pdf))
                        os.remove(path_pdf_i)
                    print("Finished deleting all ancient PDFs")

                    # now let us delete the ancient coverage maps
                    npy_files = [file for file in os.listdir(scene_dir) if file.endswith(".npy")]
                    for npy in npy_files:
                        path_npy_i = os.path.join(scene_dir, str(npy))
                        os.remove(path_npy_i)
                    print("Finished deleting all ancient npys")
        
                    # let us delete all the ancient rendered scenes
                    rendered_scene = [file for file in os.listdir(scene_dir) if file.endswith(".png")]
                    print(f"Rendered scenes: {rendered_scene}")
                    if rendered_scene:
                        os.remove(os.path.join(scene_dir, str(rendered_scene[0])))


            '''if pdf_files:
                print("Skipping this DIR, CMs already computed!")
                continue'''

            # else:

            # let us get the .xml file
            xml_file = [os.path.join(scene_dir, file) for file in os.listdir(scene_dir) if file.endswith(".xml")]
            print(f"XML file -> {xml_file}")

            # try to load the scene, if it fails save the log
            try: 
                scene = sionna.rt.load_scene(xml_file[0])
                scene_size_x = scene.size[0]
                scene_size_y = scene.size[1]
                print(f"We loaded the scene")
                print(f"This is the size of the scene:{scene.size}")

                # let us render the scene
                my_cam = Camera("my_cam", position=[-250,250,150], look_at=[0,0,0])
                scene.add(my_cam)
                if render_to_file:
                    scene.render_to_file(camera="my_cam", filename=os.path.join(scene_dir,"rendered_scene.png"), resolution=[650,500])
                scene.remove("my_cam")

                # let us now specify the frequency of the scene
                scene.frequency = 3.5e9
                print(f"This is the frequency of the scene:{scene.frequency} ")

            except Exception as exception:
                print(f"An error has occurred --> {exception}")
                print(f"Checking the error_log file")
                current_time = datetime.datetime.now() # to identify the date and time when the exception arised  

                # Check if the file exists, if not, create it
                if not os.path.exists(error_file_path):
                    with open(error_file_path, "w") as file:
                        file.write(f"{current_time} ---> Exception: {exception}.\n")  # Writing inside the file
                        print(f"File '{error_file_path}' created and error written successfully.")
                else:
                    with open(error_file_path, "a") as file:  # Append mode to avoid overwriting
                        file.write(f"{current_time} ---> Exception: {exception}.\n")  # Writing inside the file
                        print(f"File '{error_file_path}' already exists. Added a new line.")

                print(f"\nScene could not be loaded, saving the output on the .txt")
                continue

            # the scene is loaded correctly, let us now retrieve the relevant antenna parameters
            df = pd.read_csv("datos_antenas_Madrid_191124.csv", sep=";") # Replace with your file path
            orientations, gants, alturas, tilts = extract_data(df,name)

            # let us compute the coverage map
            num_antennas = len(orientations)
            tx_power = 0 # If we define the Tx power as 0 dBm we are going to obtain instead of received signal the pathloss
            gain_tr38901 = 8 # double check the value in case of doubt

            # This loop defines each transmitter
            tensor_list = [] 
            for i in range(num_antennas):
                print(f"Sector number {i}")
                transmitter = Transmitter(name=f"tx_{i+1}",
                                          position=[0,0,alturas[i]],
                                          orientation = [np.deg2rad(orientations[i]), np.deg2rad(tilts[i]), 0], # ToDo adjust reference angles
                                          power_dbm = tx_power + gants[i] - gain_tr38901) # We are considering here the PIRE: ToDo Substract the gain of the radiation patter we use

                scene.add(transmitter)
                scene.tx_array = PlanarArray(num_rows=1,
                                             num_cols=1,
                                             vertical_spacing=0.5,  # relative to wavelength
                                             horizontal_spacing=0.5,  # relative to wavelength
                                             pattern="tr38901",
                                             polarization="V")

                scene.rx_array = scene.tx_array

                # define a camera to save the coverage map
                camera_1 = Camera(name = 'testing_camera', position=[0, 0, 300], look_at=[0, 0, 0])

                max_depth = 8
                num_samples = int(10e6)
                cm = scene.coverage_map(max_depth=max_depth,           # Maximum number of ray scene interactions
                                        num_samples=num_samples, # If you increase: less noise, but more memory required
                                        diffraction = True,
                                        cm_cell_size=(2, 2),   # Resolution of the coverage map
                                        cm_center=[0, 0, 1.5],   # Center of the coverage map, 1.5 m for the Rx_height
                                        cm_size=[int(scene_size_x), int(scene_size_y)],    # Total size of the coverage map
                                        cm_orientation=[0, 0, 0])
                cm1 = cm
                cm_image = cm.show(metric = cm_metric, vmin = -200, vmax = -50)

                # if cm1 == cm: print(f"Both tensors are equal")

                # let us save the CM
                cm_image.savefig(os.path.join(scene_dir, f"sector_{orientations[i]}_md-{str(max_depth)}_ns-{str(num_samples)}.pdf"))

                # let us save the CM as a tensor in both natural units and in dBs
                cm_tensor_natural = cm.rss
                # print(f"\n Original tensor with no conversion: {cm_tensor_natural}\n")

                cm_tensor_dB = watt_to_dbm(cm_tensor_natural)
                cm_tensor_dB = np.nan_to_num(cm_tensor_dB, nan=-220, posinf = -220, neginf = -220)

                # cm_tensor_dB = 30 + 10*np.log10(cm_tensor_natural)
                # cm_tensor_dB = np.nan_to_num(cm_tensor_dB, nan=-220, posinf = -220, neginf = -220)
                # print(f"This is the tensor with np.log10: {cm_tensor_np_dB}")

                # Avoid NaN values and + || - infty
                min_val = tf.reduce_min(tf.where(tf.math.is_nan(cm_tensor_dB), tf.constant(float('inf')), cm_tensor_dB))
                print(f"Min value of the tensor: {min_val}")
                print(type(cm_tensor_dB))
                print(tf.shape(cm_tensor_dB))

                tensor_list.append(cm_tensor_dB)
                print(f"This is the shape of the tensor with no mods:{tf.shape(cm_tensor_natural)}")
                print(f"Content of the tensor_list: {tensor_list}")
                
                # has_nonzero = tf.reduce_any(cm_tensor_natural != 0)
                # print(f"Elements inside the tensor != 0:{has_nonzero} ")
                
                plt.close("all") # close the image to avoid memory consumption

                # Free memory properly
                del cm, cm_tensor_natural, cm_tensor_dB
                gc.collect()  # Force memory cleanup

                scene.remove(f"tx_{i+1}")

            final_tensor = tf.stack(tensor_list, axis = 0)
            print(f"Shape of the final tensor: {tf.shape(final_tensor)}")
            print(f"Content of the final tensor: {final_tensor}")

            # let's turn it into a npy variable
            # final_tensor_npy = final_tensor.numpy()

            # let's save the tensor in a .npy file
            np.save(os.path.join(scene_dir,"cm_tensor_dB.npy"), final_tensor.numpy().astype(np.float32))

            # clean all tensor variables
            tensor_list = [] 
            final_tensor = []
            tf.keras.backend.clear_session()
            
            # Clear scene after each folder
            del scene, df
            gc.collect()

# %% [markdown]
# ### Delete ancient tensors and coverage maps

# %%
# directories = ["sionna_madrid" ,"sionna_madrid_concrete_ground"]
# for directory in directories:
#     for name in os.listdir(directory):
#         # if os.path.isdir(os.path.join(directory, name)) and name != ".ipynb_checkpoints" and name not in ["2800930", "2800754"]:
#         if os.path.isdir(os.path.join(directory, name)) and name != ".ipynb_checkpoints":
#             scene_dir = os.path.join(directory, name)

#             # let us delete the ancient PDFs
#             pdf_files = [file for file in os.listdir(scene_dir) if file.endswith(".pdf")]
#             for pdf in pdf_files:
#                 path_pdf_i = os.path.join(scene_dir, str(pdf))
#                 os.remove(path_pdf_i)
#             print("Finished deleting all ancient PDFs")

#             # now let us delete the ancient coverage maps
#             npy_files = [file for file in os.listdir(scene_dir) if file.endswith(".npy")]
#             for npy in npy_files:
#                 path_npy_i = os.path.join(scene_dir, str(npy))
#                 os.remove(path_npy_i)
#             print("Finished deleting all ancient npys")

#             # let ubs delete all the ancient rendered scenes
#             rendered_scene = [file for file in os.listdir(scene_dir) if file.endswith(".png")]
#             print(f"Rendered scenes: {rendered_scene}")
#             if rendered_scene:
#                 os.remove(os.path.join(scene_dir, str(rendered_scene[0])))
# Out:
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# ...
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: []
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: []
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: []
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: []
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: []
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: []
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: []
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: []
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: []
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: []
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: []
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: []
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: []
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: []
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: []
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: []
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: []
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: []
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: []
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: []
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: []
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: []
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: []
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: []
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: []
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: []
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: []
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: []
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: []
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: []
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: []
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: []
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: []
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: []
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: []
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: []
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: []
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: []
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: []
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: []
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: []
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: []
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: []
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: []
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: []
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: []
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: []
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: []
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: []
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: []
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: []
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: []
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: []
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: []
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: []
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: []
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: []
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: []
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: []
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: []
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: []
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: []
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: []
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: []
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: []
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: []
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: []
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: []
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: []
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: []
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: []
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: []
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: []
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: []
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: []
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: []
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: []
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: []
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: []
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: []
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: []
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: []
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: []
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: []
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: []
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: []
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: []
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: []
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: []
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: []
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: []
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: []
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: []
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: []
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: []
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: []
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: []
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: []
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: []
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: []
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: ['rendered_scene.png']
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: []
# Finished deleting all ancient PDFs
# Finished deleting all ancient npys
# Rendered scenes: []

# %% [markdown]
# ### Adding light to the scenes by modifying the `.xml` file $\text{\textcolor{red}{ONLY RUN IT ONCE!}}$

# %%
# import os

# # Define the emitter block to be added
# emitter_block = """\n<!-- Emitters -->
#     <emitter type="constant" id="World">
#         <rgb value="1.000000 1.000000 1.000000" name="radiance"/>
#     </emitter>\n"""

# def add_emitter_to_xml(directory):
#     """Adds an emitter block before the closing </scene> tag in all XML files in the directory."""

#     directories = ["sionna_madrid" ,"sionna_madrid_concrete_ground"]
#     for directory in directories:
#         error_file_path = os.path.join(directory, "error_logs.txt")
#         for name in os.listdir(directory):
#             # if os.path.isdir(os.path.join(directory, name)) and name != ".ipynb_checkpoints" and name not in ["2800930", "2800754"]:
#             if os.path.isdir(os.path.join(directory, name)) and name != ".ipynb_checkpoints":
#                 scene_dir = os.path.join(directory, name)
#                 for filename in os.listdir(scene_dir):
#                     if filename.endswith(".xml"):
#                         file_path = os.path.join(scene_dir, filename)
#                         print(file_path)
                        
#                         # Read the XML file
#                         with open(file_path, "r", encoding="utf-8") as file:
#                             content = file.read()
            
#                         # Ensure we add the emitter block before the </scene> tag
#                         if "</scene>" in content:
#                             new_content = content.replace("</scene>", emitter_block + "</scene>")
                            
#                             # Write back the modified content
#                             with open(file_path, "w", encoding="utf-8") as file:
#                                 file.write(new_content)
                            
#                             print(f"Updated: {filename}")

# # Specify the directory where the XML files are located
# directory = "sionna_madrid/2800001"
# add_emitter_to_xml(directory)

# print("Processing completed.")

# # let's try to load a scene in Sionna
# scene = sionna.rt.load_scene('sionna_madrid/2800001/scene.xml')
# scene.preview()

# %% [markdown]
# ## Removing light dupllicates in scenes

# %%
# import os
# import re

# def remove_duplicate_emitters(directory):
#     """Removes duplicate emitter blocks from all XML files in the directory."""
#     for directory in directories:
#         for name in os.listdir(directory):
#             # if os.path.isdir(os.path.join(directory, name)) and name != ".ipynb_checkpoints" and name not in ["2800930", "2800754"]:
#             if os.path.isdir(os.path.join(directory, name)) and name != ".ipynb_checkpoints":
#                 scene_dir = os.path.join(directory, name)
#                 for filename in os.listdir(scene_dir):
#                     if filename.endswith(".xml"):
#                         file_path = os.path.join(scene_dir, filename)
#                         print(file_path)

#                         with open(file_path, "r", encoding="utf-8") as file:
#                             content = file.read()

#                         # Define the emitter block pattern (allowing for variable spacing)
#                         emitter_pattern = r"(<!-- Emitters -->\s*<emitter type=\"constant\" id=\"World\">\s*<rgb value=\"1\.000000 1\.000000 1\.000000\" name=\"radiance\"/>\s*</emitter>\s*)"

#                         # Find all emitter blocks
#                         emitters = re.findall(emitter_pattern, content, re.DOTALL)

#                         if len(emitters) > 1:
#                             # Keep only one and remove duplicates
#                             new_content = re.sub(emitter_pattern, "", content, count=len(emitters) - 1)

#                             # Write the cleaned content back to the file
#                             with open(file_path, "w", encoding="utf-8") as file:
#                                 file.write(new_content)

#                             print(f"Updated: {filename} (removed {len(emitters) - 1} duplicate emitter(s))")
#                         else:
#                             print(f"No duplicates found in: {filename}")

# # Specify the directory containing XML files
# directory = "sionna_madrid_concrete_ground"
# remove_duplicate_emitters(directory)

# print("Processing completed.")
# Out:
# sionna_madrid/2810915/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2803334/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800051/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2805631/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2802388/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2807999/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2803015/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2802418/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2803003/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2807969/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800310/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800042/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800236/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2804353/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2805467/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2802885/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2801791/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2801497/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800303/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2803271/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2802477/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2803062/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2806372/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2807459/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800709/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2803871/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2806222/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800360/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2806648/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2802632/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2802201/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2808150/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800757/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800400/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2801696/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800044/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800202/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2804546/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2801644/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800046/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2805664/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800242/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2803937/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2802773/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2802483/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2803578/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2801307/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2806508/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2805887/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2802394/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2806979/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2801555/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2806511/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2802886/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2802770/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2809409/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2805873/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800199/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2803648/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2805217/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2803378/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2805665/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2802789/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2803217/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800061/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800357/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2802559/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2802491/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2802139/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800352/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2803018/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800930/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2809548/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2803092/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2801711/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2801888/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800219/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2802334/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800267/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2802342/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2801663/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2806016/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2801598/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2805441/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800162/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800121/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800624/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2806528/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2808796/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2809793/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2811486/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2801705/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2802351/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2804718/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2805980/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2805161/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2805989/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2803027/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2806582/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2811394/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2806536/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2801487/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2803204/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800106/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800214/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800371/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800160/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800401/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800368/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2802430/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800399/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2802324/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2809488/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2801730/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2803331/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2802933/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2806679/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2803288/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2807290/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2803221/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2804503/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800777/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800278/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2802347/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800427/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800380/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2801539/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2801687/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2809544/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2803653/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800007/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800407/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2801657/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2803862/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2805883/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2805917/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2806492/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800253/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800210/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2808842/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2802189/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800792/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2806035/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800146/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2805150/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2803071/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2805244/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2802299/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2802995/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2803242/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2806532/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2802584/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2803223/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800489/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2805310/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2807650/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2801571/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2806426/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2807508/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2805598/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2806355/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2808759/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800911/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2801305/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2806853/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2808105/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2802971/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800659/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2802385/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2806010/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2806707/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800245/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800012/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2802764/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800393/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800931/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2805056/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2801520/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2806928/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800222/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2806509/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2802203/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2802376/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800566/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2804518/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2806151/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800098/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2801698/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800741/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2803220/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800144/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2802200/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2801780/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2804363/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2808422/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800163/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800927/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800356/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2802682/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2805891/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2802630/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800034/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2808246/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800383/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2806527/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800743/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2803984/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2804645/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2802187/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800422/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2807655/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2805137/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2811479/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2805977/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800362/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2803073/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2810447/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2802631/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2805764/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800205/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800087/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2802291/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800758/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2803888/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800307/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2806353/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800905/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2804989/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2810729/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800744/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2808132/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2811638/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2805169/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2803237/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800279/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2808942/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2801543/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2804716/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2805030/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2804519/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2801932/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800097/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800021/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800377/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2806636/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2802778/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2807852/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2803098/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2802117/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2802437/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2802322/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2811283/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2801760/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2805923/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800047/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2805790/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800384/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2802194/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2801545/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2803099/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2805830/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2803324/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2803060/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2803533/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2802434/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2804352/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2802057/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2802417/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2805870/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2805536/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2803046/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2802146/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2806001/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2802195/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800622/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800220/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800398/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2801538/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800513/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800367/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2805822/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2807997/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800381/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2802186/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2801468/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2801769/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800018/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800177/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2801727/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2806767/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2801463/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2802763/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2801488/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2801828/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2802212/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2805091/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800306/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2803290/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2801556/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2802354/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2806223/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2801546/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2806510/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2802373/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2801306/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2805178/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2807324/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2805599/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2803628/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2802333/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2805866/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800746/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2803216/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800939/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2809469/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2809401/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2802402/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2803675/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2802798/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800003/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800385/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2809583/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800417/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800937/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2805868/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2802206/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800941/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2810061/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2805425/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2805578/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2802435/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2802143/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800116/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2801490/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2802792/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2803962/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2803715/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2806007/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800796/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2801467/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800148/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2802196/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2808819/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800101/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2806002/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2803229/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2812427/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800276/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2806423/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800755/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2806891/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2802787/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2803513/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800013/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2802026/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800754/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800203/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800487/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2802142/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2802190/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2801491/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2802797/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2802775/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2809526/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2802887/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2802972/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2805057/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2806034/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2802141/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2802482/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800485/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2802392/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2809736/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2803095/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800110/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2803683/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800099/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2802312/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800392/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800382/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2804449/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800751/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800117/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800184/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2805976/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2809497/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2808333/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800723/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800415/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800910/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2801506/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2808429/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800408/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2805926/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2802015/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2804362/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2805426/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800942/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2802986/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2801503/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2802295/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800291/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2801664/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2803534/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800246/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800016/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2802461/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2804597/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2801692/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2802294/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2803663/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2804735/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2801935/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2806166/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2805924/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2805243/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800390/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2811705/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2804942/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800254/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800158/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2803282/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800102/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2803093/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2806014/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800764/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800378/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2806824/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2805499/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2805791/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2801502/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2804658/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800423/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2809511/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2803980/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2806160/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2809500/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2802776/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2805242/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2801602/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2802884/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2811625/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2801690/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2806150/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2806017/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800936/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2803503/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2803094/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2803323/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800406/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2804499/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800172/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2804641/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2805935/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2801638/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2802192/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800421/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800145/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2802769/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2803836/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2802021/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2805577/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2801461/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2804644/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2802487/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2809056/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2802767/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800364/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2802370/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2802422/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2805960/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2803096/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2803208/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800355/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2808053/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800391/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2801699/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2805151/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2811464/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2803522/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800762/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2808483/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2810304/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2802215/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2809004/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2802121/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800922/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800512/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2803022/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2803074/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2806706/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2803551/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2808174/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2801517/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2802765/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800482/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800921/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2807690/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800055/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2802786/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2802799/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2803721/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2806635/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2801647/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2806929/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2802423/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2806485/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800134/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2801519/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800052/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2802127/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2802056/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2804349/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800313/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2807720/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2811687/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2803252/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2803040/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800059/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800331/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2802967/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2802473/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2805988/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800020/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2805781/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800006/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800412/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2805367/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2801308/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2805559/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2809560/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2801700/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800791/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2807213/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2806173/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800096/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2803987/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800370/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2806234/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800201/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2809967/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2802977/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2802140/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2809337/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800354/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2805684/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800932/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2808237/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2802358/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800237/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800030/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2806422/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800194/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2809768/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2808460/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2805469/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2805575/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2806233/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800284/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2803214/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2802367/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2803232/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2803944/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2802450/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2804972/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2805031/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800209/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2805089/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800026/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2803874/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2802216/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800361/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800180/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2801516/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2810714/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2805885/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800041/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2801948/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800249/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800240/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2807687/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2801499/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2802404/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2802290/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2803911/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800001/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800215/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2808972/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800175/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800394/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2803552/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2802413/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800185/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2805368/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2807722/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2802184/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800304/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2805532/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800067/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800786/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2803097/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2808417/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2805179/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2806823/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2810564/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800309/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2802447/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2801947/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2809528/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2806036/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2802458/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2803731/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2807214/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800783/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2811622/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800353/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2806161/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800270/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800027/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800023/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2808199/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2802938/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2803746/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2801938/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2802341/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2809360/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2801550/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800156/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2809556/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2801471/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800488/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2803737/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2802109/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800229/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2805032/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2802115/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2802451/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800005/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2810423/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2802340/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800181/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800009/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800584/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2803531/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2805892/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2802945/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800100/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2809263/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800227/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800376/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800639/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2805258/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2805927/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2811711/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2802077/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2805440/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800262/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2802375/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2802349/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800919/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800775/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2801980/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2805141/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2802214/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2804794/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2803867/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2809415/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2804428/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2802185/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800243/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2808049/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2805490/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800010/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2808168/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2804558/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2806009/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2806870/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2803225/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2804527/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2801731/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800748/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800147/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2803233/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2803205/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2802478/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2803240/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2800157/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid/2809896/scene.xml
# No duplicates found in: scene.xml
# sionna_madrid_concrete_ground/2810915/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2803334/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2800051/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2805631/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2802388/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2807999/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2803015/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2802418/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2803003/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2807969/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2800310/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2800042/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2800236/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2804353/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2805467/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2802885/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2801791/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2801497/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2800303/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2803271/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2802477/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2803062/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2806372/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2807459/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2800709/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2803871/scene.xml
# ...
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2805559/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2809560/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2801700/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2800791/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2807213/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2806173/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2800096/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2803987/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2800370/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2806234/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2800201/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2809967/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2802977/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2802140/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2809337/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2800354/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2805684/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2800932/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2808237/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2802358/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2800237/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2800030/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2806422/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2800194/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2809768/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2808460/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2805469/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2805575/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2806233/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2800284/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2803214/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2802367/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2803232/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2803944/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2802450/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2804972/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2805031/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2800209/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2805089/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2800026/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2803874/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2802216/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2800361/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2800180/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2801516/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2810714/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2805885/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2800041/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2801948/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2800249/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2800240/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2807687/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2801499/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2802404/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2802290/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2803911/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2800001/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2800215/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2808972/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2800175/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2800394/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2803552/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2802413/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2800185/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2805368/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2807722/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2802184/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2800304/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2805532/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2800067/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2800786/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2803097/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2808417/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2805179/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2806823/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2810564/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2800309/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2802447/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2801947/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2809528/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2806036/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2802458/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2803731/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2807214/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2800783/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2811622/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2800353/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2806161/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2800270/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2800027/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2800023/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2808199/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2802938/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2803746/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2801938/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2802341/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2809360/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2801550/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2800156/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2809556/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2801471/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2800488/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2803737/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2802109/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2800229/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2805032/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2802115/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2802451/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2800005/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2810423/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2802340/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2800181/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2800009/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2800584/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2803531/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2805892/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2802945/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2800100/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2809263/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2800227/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2800376/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2800639/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2805258/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2805927/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2811711/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2802077/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2805440/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2800262/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2802375/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2802349/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2800919/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2800775/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2801980/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2805141/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2802214/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2804794/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2803867/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2809415/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2804428/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2802185/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2800243/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2808049/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2805490/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2800010/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2808168/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2804558/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2806009/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2806870/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2803225/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2804527/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2801731/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2800748/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2800147/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2803233/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2803205/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2802478/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2803240/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2800157/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# sionna_madrid_concrete_ground/2809896/scene.xml
# Updated: scene.xml (removed 1 duplicate emitter(s))
# Processing completed.

# %% [markdown]
# ### Rendering the scene images

# %%
# import os

# render_to_file = True
# def rendering_scenes():
#     """Adds an emitter block before the closing </scene> tag in all XML files in the directory."""

#     directories = ["sionna_madrid_concrete_ground"]
#     for directory in directories:
#         error_file_path = os.path.join(directory, "error_logs.txt")
#         for name in os.listdir(directory):
#             # if os.path.isdir(os.path.join(directory, name)) and name != ".ipynb_checkpoints" and name not in ["2800930", "2800754"]:
#             if os.path.isdir(os.path.join(directory, name)) and name != ".ipynb_checkpoints":
#                 scene_dir = os.path.join(directory, name)
#                 # print(scene_dir)
                
#                 png_files = [file for file in os.listdir(scene_dir) if file.endswith(".png")]
#                 print(f"{png_files}")

#                 if not png_files:
#                     # let us load the scene and render the image to a file
#                     xml_file = [os.path.join(scene_dir, file) for file in os.listdir(scene_dir) if file.endswith(".xml")]
#                     print(f"XML files: {xml_file}")
#                     # scene_path = os.path.join(scene_dir, xml_file)
#                     print(f"No hay escenas computadas, computamos;{xml_file[0]}")
#                     scene = sionna.rt.load_scene(xml_file[0])
#                     # let us render the scene
#                     my_cam = Camera("my_cam", position=[-250,250,150], look_at=[0,0,0])
#                     scene.add(my_cam)
#                     if render_to_file:
#                         scene.render_to_file(camera="my_cam", filename=os.path.join(scene_dir,"rendered_scene.png"), resolution=[650,500])
#                     scene.remove("my_cam")
#                     del scene, my_cam
                    
#     #         file_path = os.path.join(scene_dir, filename)


# rendering_scenes()

# print("Processing completed.")

# # let's try to load a scene in Sionna
# # scene = sionna.rt.load_scene('sionna_madrid/2800001/scene.xml')
# # scene.preview()

# %% [markdown]
# # Main code again to run after the cell above

# %%
import datetime
import gc

cm_metric = "rss" # choose between: ["path_gain", "rss", "SINR"]
delete_previous_results = False
render_to_file = False

# First, let's start by retrieving the coords of the BS by getting the name of the folder and searching by its name on the dataset
directories = ["sionna_madrid" ,"sionna_madrid_concrete_ground"]
for directory in directories:
    error_file_path = os.path.join(directory, "error_logs.txt")
    for name in os.listdir(directory):
        # if os.path.isdir(os.path.join(directory, name)) and name != ".ipynb_checkpoints" and name not in ["2800930", "2800754"]:
        if os.path.isdir(os.path.join(directory, name)) and name != ".ipynb_checkpoints":
            print(f"Element: {name}")
            # cwd = os.getcwd()
            scene_dir = os.path.join(directory, name)
            # print(scene_dir)

            # if desired, delete previous results to purge directories
            if delete_previous_results:
                if os.path.isdir(os.path.join(directory, name)) and name != ".ipynb_checkpoints":
                    scene_dir = os.path.join(directory, name)
        
                    # let us delete the ancient PDFs
                    pdf_files = [file for file in os.listdir(scene_dir) if file.endswith(".pdf")]
                    for pdf in pdf_files:
                        path_pdf_i = os.path.join(scene_dir, str(pdf))
                        os.remove(path_pdf_i)
                    print("Finished deleting all ancient PDFs")
        
                    # now let us delete the ancient coverage maps
                    npy_files = [file for file in os.listdir(scene_dir) if file.endswith(".npy")]
                    for npy in npy_files:
                        path_npy_i = os.path.join(scene_dir, str(npy))
                        os.remove(path_npy_i)
                    print("Finished deleting all ancient npys")
        
                    # let us delete all the ancient rendered scenes
                    rendered_scene = [file for file in os.listdir(scene_dir) if file.endswith(".png")]
                    print(f"Rendered scenes: {rendered_scene}")
                    if rendered_scene:
                        os.remove(os.path.join(scene_dir, str(rendered_scene[0])))
            

            '''if pdf_files:
                print("Skipping this DIR, CMs already computed!")
                continue'''

            # else:

            # let us get the .xml file
            xml_file = [os.path.join(scene_dir, file) for file in os.listdir(scene_dir) if file.endswith(".xml")]
            print(f"XML file -> {xml_file}")

            # try to load the scene, if it fails save the log
            try: 
                scene = sionna.rt.load_scene(xml_file[0])
                scene_size_x = scene.size[0]
                scene_size_y = scene.size[1]
                print(f"We loaded the scene")
                print(f"This is the size of the scene:{scene.size}")

                # let us render the scene
                my_cam = Camera("my_cam", position=[-250,250,150], look_at=[0,0,0])
                scene.add(my_cam)
                if render_to_file:
                    scene.render_to_file(camera="my_cam", filename=os.path.join(scene_dir,"rendered_scene.png"), resolution=[650,500])
                scene.remove("my_cam")

                # let us now specify the frequency of the scene
                scene.frequency = 3.5e9
                print(f"This is the frequency of the scene:{scene.frequency} ")

            except Exception as exception:
                print(f"An error has occurred --> {exception}")
                print(f"Checking the error_log file")
                current_time = datetime.datetime.now() # to identify the date and time when the exception arised  

                # Check if the file exists, if not, create it
                if not os.path.exists(error_file_path):
                    with open(error_file_path, "w") as file:
                        file.write(f"{current_time} ---> Exception: {exception}.\n")  # Writing inside the file
                        print(f"File '{error_file_path}' created and error written successfully.")
                else:
                    with open(error_file_path, "a") as file:  # Append mode to avoid overwriting
                        file.write(f"{current_time} ---> Exception: {exception}.\n")  # Writing inside the file
                        print(f"File '{error_file_path}' already exists. Added a new line.")

                print(f"\nScene could not be loaded, saving the output on the .txt")
                continue

            # the scene is loaded correctly, let us now retrieve the relevant antenna parameters
            df = pd.read_csv("datos_antenas_Madrid_191124.csv", sep=";") # Replace with your file path
            orientations, gants, alturas, tilts = extract_data(df,name)

            # let us compute the coverage map
            num_antennas = len(orientations)
            tx_power = 0 # If we define the Tx power as 0 dBm we are going to obtain instead of received signal the pathloss
            gain_tr38901 = 8 # double check the value in case of doubt

            # This loop defines each transmitter
            tensor_list = [] 
            for i in range(num_antennas):
                print(f"Sector number {i}")
                transmitter = Transmitter(name=f"tx_{i+1}",
                                          position=[0,0,alturas[i]],
                                          orientation = [np.deg2rad(orientations[i]), np.deg2rad(tilts[i]), 0], # ToDo adjust reference angles
                                          power_dbm = tx_power + gants[i] - gain_tr38901) # We are considering here the PIRE: ToDo Substract the gain of the radiation patter we use

                scene.add(transmitter)
                scene.tx_array = PlanarArray(num_rows=1,
                                             num_cols=1,
                                             vertical_spacing=0.5,  # relative to wavelength
                                             horizontal_spacing=0.5,  # relative to wavelength
                                             pattern="tr38901",
                                             polarization="V")

                scene.rx_array = scene.tx_array

                # define a camera to save the coverage map
                camera_1 = Camera(name = 'testing_camera', position=[0, 0, 300], look_at=[0, 0, 0])

                max_depth = 8
                num_samples = int(10e6)
                cm = scene.coverage_map(max_depth=max_depth,           # Maximum number of ray scene interactions
                                        num_samples=num_samples, # If you increase: less noise, but more memory required
                                        diffraction = True,
                                        cm_cell_size=(2, 2),   # Resolution of the coverage map
                                        cm_center=[0, 0, 1.5],   # Center of the coverage map, 1.5 m for the Rx_height
                                        cm_size=[int(scene_size_x), int(scene_size_y)],    # Total size of the coverage map
                                        cm_orientation=[0, 0, 0])
                cm1 = cm
                cm_image = cm.show(metric = cm_metric, vmin = -200, vmax = -50)

                # if cm1 == cm: print(f"Both tensors are equal")

                # let us save the CM
                cm_image.savefig(os.path.join(scene_dir, f"sector_{orientations[i]}_md-{str(max_depth)}_ns-{str(num_samples)}.pdf"))

                # let us save the CM as a tensor in both natural units and in dBs
                cm_tensor_natural = cm.rss
                # print(f"\n Original tensor with no conversion: {cm_tensor_natural}\n")
                epsilon = 1e-10 # to avoid -Inf as result

                cm_tensor_dB = watt_to_dbm(cm_tensor_natural)
                cm_tensor_dB = np.nan_to_num(cm_tensor_dB, nan=-220, posinf = -220, neginf = -220)

                # cm_tensor_dB = 30 + 10*np.log10(cm_tensor_natural)
                # cm_tensor_dB = np.nan_to_num(cm_tensor_dB, nan=-220, posinf = -220, neginf = -220)
                # print(f"This is the tensor with np.log10: {cm_tensor_np_dB}")

                # Avoid NaN values and + || - infty
                min_val = tf.reduce_min(tf.where(tf.math.is_nan(cm_tensor_dB), tf.constant(float('inf')), cm_tensor_dB))
                print(f"Min value of the tensor: {min_val}")
                print(type(cm_tensor_dB))
                print(tf.shape(cm_tensor_dB))

                tensor_list.append(cm_tensor_dB)
                print(f"This is the shape of the tensor with no mods:{tf.shape(cm_tensor_natural)}")
                print(f"Content of the tensor_list: {tensor_list}")
                
                # has_nonzero = tf.reduce_any(cm_tensor_natural != 0)
                # print(f"Elements inside the tensor != 0:{has_nonzero} ")
                
                plt.close("all") # close the image to avoid memory consumption

                # Free memory properly
                del cm, cm_tensor_natural, cm_tensor_dB
                gc.collect()  # Force memory cleanup

                scene.remove(f"tx_{i+1}")

            final_tensor = tf.stack(tensor_list, axis = 0)
            print(f"Shape of the final tensor: {tf.shape(final_tensor)}")
            print(f"Content of the final tensor: {final_tensor}")

            # let's turn it into a npy variable
            # final_tensor_npy = final_tensor.numpy()

            # let's save the tensor in a .npy file
            np.save(os.path.join(scene_dir,"cm_tensor_dB.npy"), final_tensor.numpy().astype(np.float32))

            # clean all tensor variables
            tensor_list = [] 
            final_tensor = []
            tf.keras.backend.clear_session()
            
            # Clear scene after each folder
            del scene, df
            gc.collect()
